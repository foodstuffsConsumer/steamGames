# %%
import pandas as pd
import matplotlib.pyplot as plt
import time

quit = False

original_df = pd.read_csv('Data/games.csv')

filtered_df = original_df.drop(columns=['Release Date', 'Rating', 'Unnamed: 0', 'Team', 'Number of Reviews', 'Times Listed', 'Summary', 'Reviews', 'Backlogs', 'Wishlist'])

unduped_df = filtered_df.drop_duplicates

def convert(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000

unduped_df['Plays'] = unduped_df['Plays'].apply(convert)

sorted_df = unduped_df.sort_value(by=['Plays'], ascending=False).head(50)


def showOriginal():
    print(original_df)

def showCleaned():
    print(sorted_df)

def showChart():
    filtered_df.plot(
                    kind='bar',
                    x='Genres',
                    y='Plays',
                    color='blue',
                    alpha=0.3,
                    title='Most Popular Video Game Genre')
    plt.show()

def userOptions():
    global quit

    selection = input(("""Welcome to the Game Data Visualiser.
          
    Type the following numbers as options:
    1 - Show the original game dataset.
    2 - Show the filtered game dataset.
    3 - Visualise the most popular video game genre.
    4 - Quit the program.
        """))

    if selection == '1':
            showOriginal()
            time.sleep(1.5)
            
    elif selection == '2':
            showCleaned()
            time.sleep(1.5)
    elif selection == '3':
            showChart()
            time.sleep(1.5)
    elif selection == '4':
            quit = True
    else:
        print("Sorry, I didn't quite understand that.")
        time.sleep(1.5)

   

#----Main program----#
while not quit:
    userOptions()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 21
#      18             return float(x.replace('K', '')) * 1000
#      19         return 1000
# ---> 21 unduped_df['Plays'] = unduped_df['Plays'].apply(convert)
#      23 sorted_df = unduped_df.sort_value(by=['Plays'], ascending=False).head(50)
#      26 def showOriginal():
#
# TypeError: 'method' object is not subscriptable
