# %% [markdown]
# # Identifying and Defining
# - Data - A collection of the most popular games from 2000 to 2023
# - Goal - To find out the most popular genre of video game
# - Source - https://www.kaggle.com/datasets/arnabchaki/popular-video-games-1980-2023
# - Access - Publicly available
# - File - .csv
#
# ### Functional Requirements
# Data Loading: Should only attempt to load .csv files.
#
# Input: A .txt file or any other file type.
#
# Output: A message showing that the file type is incorrect.
#
# ----------------------------------------------------------
#
# Data Cleaning: Should filter out any unwanted or unneeded information.
#
# Input: A dataset, which contains important information as well as unneeded data in separate columns.
#
# Output: The dataframe, but with the unneeded columns removed.
#
# ----------------------------------------------------------
#
# Data Analysis: The user should be able to filter out sort or find certain categories, such as game genre or popularity.
#
# Input: An input asking for the most popular genre of game.
#
# Output: A message showing the most popular genre of game.
#
# ----------------------------------------------------------
#
# Data Visualisation: Should visualise the data via a Pandas dataframe.
#
# Input: A raw .csv file.
#
# Output: A dataframe displaying the information in the file.
#
# ----------------------------------------------------------
#
# Data Reporting:
#
# Input:
#
# Output:

# %% [markdown]
# # Use Cases
#
# Type: Loading
#
# Goal: To attempt to load a dataset into the system.
#
# Preconditions: User has a file of the incorrect type.
# - User places the file into the correct folder.
# - System validates the file.
# - System finds the file type is incorrect and displays a message.
# Postconditions: The incorrect file type is rejected, and the user notified.
#
# ---------------------------------------------------------------
#
# Type: Cleaning
#
# Goal: To remove any unneeded information.
#
# Preconditions: The dataset is loaded.
# - User inputs the command to clean the dataset.
# - System removes the unneeded information from the dataset.
# - System presents the clean data in the form of a dataframe.
#
# Postconditions: The dataset is cleaned and displayed as a dataframe.
#
# ---------------------------------------------------------------
#
# Type: Analysis
#
# Goal:
#
# Preconditions:
# - g
# - g
# - g
#
# Postconditions:
#
# ---------------------------------------------------------------
#
# Type: Visualisation
#
# Goal: To load a dataset into the system.
#
# Preconditions: User has a valid dataset file ready.
# - User places the dataset in the correct folder.
# - System validates the file.
# - System finds the file format is correct and displays the dataset in a dataframe.
#
# Postconditions: The dataset is loaded and ready for analysis.
#
# ---------------------------------------------------------------
#
# Type: Reporting
#
# Goal:
#
# Preconditions:
# - g
# - g
# - g
#
# Postconditions:
